# %%
cd ../data/external/
# Out:
# [Errno 2] No such file or directory: '../data/external/'
# /Users/showta/project/wovle/data/external

# %%
w = pd.read_pickle('./w2v50.pd')

# %%
w.head()
# Out:
#               0         1         2         3         4         5         6  \
# 単語
# !      0.085313 -0.315384 -0.092300 -0.248376  0.086111 -0.157666  0.077312
# !!    -0.045048 -0.321234  0.027998 -0.151201 -0.119650 -0.243689  0.130387
# !!!    0.102477 -0.294404 -0.208346 -0.237338  0.035036  0.093773  0.026998
# !!!!   0.019460 -0.155649  0.083683 -0.249125 -0.086154 -0.025289  0.085001
# !!!!」 -0.092480 -0.260534 -0.225866 -0.235766 -0.030068 -0.045762  0.292589
#
#               7         8         9   ...           42        43        44  \
# 単語                                    ...
# !     -0.099744  0.076536  0.044399   ...    -0.133331 -0.043328 -0.218630
# !!    -0.105005  0.086659 -0.030688   ...    -0.168179  0.010304 -0.024246
# !!!   -0.020967  0.037141  0.150921   ...     0.011319  0.067921  0.000899
# !!!!   0.082792  0.120148  0.157015   ...    -0.065325 -0.106615 -0.027921
# !!!!」  0.101359  0.196797  0.164433   ...     0.092940 -0.179500  0.095535
#
# ...

# %%
w = w[w.isNWord == True]

# %%
w = w.ix[:,0:50]

# %%
w.head()
# Out:
#              0         1         2         3         4         5         6   \
# 単語
# $0    -0.091570 -0.250394 -0.286804 -0.293840  0.083906  0.231383  0.082306
# $1    -0.183222 -0.241146 -0.164868 -0.272110  0.118274  0.151662  0.140846
# $10   -0.167602 -0.193840 -0.197030 -0.244208  0.063914  0.229293  0.051763
# $100  -0.154172 -0.204950 -0.002985 -0.299257  0.066675  0.230528  0.119424
# $1000 -0.118178 -0.095207 -0.133108 -0.310237 -0.012714  0.158886  0.154072
#
#              7         8         9     ...           40        41        42  \
# 単語                                     ...
# $0     0.029567  0.093080 -0.084730    ...    -0.050905  0.340124 -0.154913
# $1    -0.061668  0.227850 -0.055724    ...    -0.069652  0.297924  0.029427
# $10    0.063416  0.191286  0.047562    ...    -0.074935  0.273996 -0.015350
# $100  -0.036147  0.129500 -0.033706    ...     0.021279  0.434230  0.038445
# $1000  0.073863  0.104023 -0.115571    ...    -0.009341  0.219370 -0.196468
#
# ...

# %%
w.shape
# Out:
# (330007, 50)
