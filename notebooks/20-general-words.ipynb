# %%
cd ./../data/external/
# Out:
# /home/saho/project/wovle/data/external

# %%
ls
# Out:
# 0         1.mecab              dictation-kit-v4.4/  w2v200_fitToDic.tsv
# 0.filted  1gm-0000             filelist             w2v50.pd
# 0.mecab   CJLC-0.1/            index.html           w2v50.tsv
# 1         csj.pdp.htkdic       w2v200.pd            w2v50_fitToDic.tsv
# 1.filted  csj.pdp.htkdic.utf8  w2v200.txt

# %%
# !head ./1gm-0000
# Out:
# "	11435722
# ""	57986
# """	1378
# "%	1360
# "&"	1524
# "'	2146
# "(	70566
# ")	23483
# "*"	1965
# "+	1074

# %%
gm = pd.read_csv('./1gm-0000', sep="\t", header=None, quoting=3)

# %%
gm.head()
# Out:
#      0         1
# 0    "  11435722
# 1   ""     57986
# 2  """      1378
# 3   "%      1360
# 4  "&"      1524

# %%
gm = gm.sort_values(by=1, ascending=False)

# %%
gm
# Out:
#                    0           1
# 5259            </S>  5634102353
# 5279             <S>  5634102353
# 43841              の  4124326304
# 25709              、  3080970756
# 43179              に  2241587693
# 44173              は  1972344221
# 54199              を  1947665622
# 41314              て  1882399603
# 32408              が  1832636418
# 39007              た  1621901048
# 41504              で  1366528153
# 41632              と  1188227624
# 36458              し  1019626967
# 144904             ・   893945565
# 50522              も   726088190
# 42576              な   645261641
# 48923             ます   625694223
# 41560             です   540141737
# 25786              「   524369976
# 42583             ない   497438083
# 25838              」   482660490
# 185                (   477915150
# 32146             から   431272999
# 856                )   421588930
# 31139              か   412161085
# 38179             する   373617907
# 39780              だ   370142678
# 35010             こと   339338762
# 54211              ん   338980183
# 27626              い   338862266
# ...              ...         ...
# 7359            CIEL        1000
# 30265            おせろ        1000
# 91759        ストラップピン        1000
# 21090          dolce        1000
# 118148           フウキ        1000
# 239              ();        1000
# 1314              +〈        1000
# 52359            ゅねん        1000
# 113252        パソカレッジ        1000
# 19751           YUZU        1000
# 63738           ウフウフ        1000
# 219239            溫泉        1000
# 192712          思ひ寄る        1000
# 159706            円価        1000
# 52899         ょうちくばい        1000
# 77835      グラデュエーション        1000
# 148245           下福田        1000
# 203733            星永        1000
# 217584            淀山        1000
# 148223           下白滝        1000
# 70647            カブー        1000
# 63093         ウェーウェー        1000
# 68745            オワル        1000
# 63013   ウェブ・アクセシビリティ        1000
# 95500         ソルトゲーム        1000
# 148106           下徳富        1000
# 254823           農工高        1000
# 53733            りん病        1000
# 169535            吸收        1000
# 107792       ニューグランデ        1000
#
# [270214 rows x 2 columns]

# %%
gm.to_csv("./gm_sorted.csv")

# %%
gm_300 = gm[0:300]

# %%
gm_300
# Out:
#             0           1
# 5259     </S>  5634102353
# 5279      <S>  5634102353
# 43841       の  4124326304
# 25709       、  3080970756
# 43179       に  2241587693
# 44173       は  1972344221
# 54199       を  1947665622
# 41314       て  1882399603
# 32408       が  1832636418
# 39007       た  1621901048
# 41504       で  1366528153
# 41632       と  1188227624
# 36458       し  1019626967
# 144904      ・   893945565
# 50522       も   726088190
# 42576       な   645261641
# 48923      ます   625694223
# 41560      です   540141737
# 25786       「   524369976
# 42583      ない   497438083
# 25838       」   482660490
# 185         (   477915150
# 32146      から   431272999
# 856         )   421588930
# 31139       か   412161085
# 38179      する   373617907
# 39780       だ   370142678
# 35010      こと   339338762
# 54211       ん   338980183
# 27626       い   338862266
# ...       ...         ...
# 26928     あなた    24363498
# 199054     掲載    24297389
# 230075     確認    24248086
# 25483       ☆    24210693
# 43400    によって    24116058
# 28123      いっ    24074460
# 156438     個人    24022668
# 84837    サービス    23951892
# 53886       わ    23900665
# 191642      心    23888649
# 36928     しまっ    23873526
# 233688      笑    23832474
# 25423       ●    23720471
# 225004      用    23624991
# 213431      氏    23307540
# 31136     お願い    23288795
# 175286     多く    23197992
# 257927      部    23080638
# 27217   ありがとう    22867956
# 222532      物    22840861
# 133630    メール    22794286
# 224797     生活    22771802
# 229776     研究    22753284
# 236182     結果    22671433
# 4902        9    22258696
# 201479      新    22142480
# 160662     出来    22114608
# 172390      国    22112309
# 234259     管理    22057592
# 204141     時代    22037301
#
# [300 rows x 2 columns]

# %%
gm_300.to_pickle("general_words_300.pd")
